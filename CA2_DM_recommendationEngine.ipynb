# %% [markdown]
# <a href="https://colab.research.google.com/github/alexoliveros92/Recommendation_engine/blob/main/CA2_DM_recommendationEngine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Movies recommendation based on ratings and description

# %%
netFlxDts = pd.read_csv("/content/NetflixCleanedDataset.csv")
netFlxDts.head(10)
# Out:
#    movie_ID                   title  year certificate  duration_min  \
# 0         1               Cobra Kai  2018       TV-14            30
# 1         2               The Crown  2016       TV-MA            58
# 2         3        Better Call Saul  2022       TV-MA            46
# 3         4           Devil in Ohio  2022       TV-MA           356
# 4         5  Cyberpunk: Edgerunners  2022       TV-MA            24
# 5         6             The Sandman  2022       TV-MA            45
# 6         7          Rick and Morty  2013       TV-MA            23
# 7         8            Breaking Bad  2013       TV-MA            49
# 8         9          The Imperfects  2022       TV-MA            45
# 9        10                  Blonde  2022       NC-17           166
#
#        genre                           Tag  rating  \
# 0     Action         Action, Comedy, Drama     8.5
# 1  Biography     Biography, Drama, History     8.7
# 2      Crime                  Crime, Drama     8.9
# 3      Drama        Drama, Horror, Mystery     5.9
# 4  Animation  Animation, Action, Adventure     8.6
# 5      Drama        Drama, Fantasy, Horror     7.8
# 6  Animation  Animation, Adventure, Comedy     9.2
# 7      Crime        Crime, Drama, Thriller     9.5
# 8     Action      Action, Adventure, Drama     6.3
# 9  Biography     Biography, Drama, Mystery     6.2
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
# 5  Upon escaping after decades of imprisonment by...
# 6  An animated series that follows the exploits o...
# 7  A high school chemistry teacher diagnosed with...
# 8  After an experimental gene therapy turns them ...
# 9  A fictionalized chronicle of the inner life of...
#
#                                                stars      votes
# 0  ['Ralph Macchio','William Zabka','Courtney Hen...    177,031
# 1  ['Claire Foy','Olivia Colman','Imelda Staunton...    199,885
# 2  ['Bob Odenkirk','Rhea Seehorn','Jonathan Banks...    501,384
# 3  ['Emily Deschanel','Sam Jaeger','Gerardo Celas...      9,773
# 4  ['Zach Aguilar','Kenichiro Ohashi','Emi Lo','A...     15,413
# 5  ['Tom Sturridge','Boyd Holbrook','Patton Oswal...    116,358
# 6  ['Justin Roiland','Chris Parnell','Spencer Gra...    502,160
# 7  ['Bryan Cranston','Aaron Paul','Anna Gunn','Be...  1,831,340
# 8  ['Morgan Taylor Campbell','Italia Ricci','Rhia...      3,123
# 9  ['Andrew Dominik','Ana de Armas','Lucy DeVito'...        935

# %%
# Droping rows with missing values in the 'description' and 'rating' columns
netFlxDts = netFlxDts.dropna(subset=['description', 'rating'])

# %%
# Create a TF-IDF vectorizer to convert movie descriptions to vectors
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(netFlxDts['description'])

# %% [markdown]
# - TfidVectorizer is used to compare the repetation of words in perticular documnets. In our code, it is being consumed to utilize the description.
#
# - fit_transform method converts the movie descriptions in the DataFrame into a TF-IDF matrix. Each row of the matrix represents a movie, and each column represents a unique word in the descriptions.

# %%
## Remove duplicate values based on titles
netFlxDts = netFlxDts.drop_duplicates(subset=['title'])

# %%
# Compute the cosine similarity matrix based on movie descriptions
cosine_sim = cosine_similarity(tfidf_matrix)

# %% [markdown]
# - Cosine Similarity is using to check the simmilarity between others tfid matrix. Based on the simmilarity we can get the movies recommendation.
#
# - The cosine similarity between two vectors is the cosine of the angle between them in a multidimensional space. It is a measure of the similarity between the two vectors, ranging from -1 (opposite directions) to 1 (same direction), with 0 indicating no correlation between the vectors.

# %%
# Create a dictionary to store the movie titles and their corresponding indices in the DataFrame
indices = pd.Series(netFlxDts.index, index=netFlxDts['title']).drop_duplicates()

# %% [markdown]
# This line constructs a reverse mapping of movie titles and indices. The resulting indices Series object has movie titles as its index and movie indices as its values. This mapping will be used later to look up the index of a movie given its title.

# %%
def get_recommendations(title):
    # Get all the indices of the movies that match the title
    indices = netFlxDts.index[netFlxDts['title'] == title].tolist()

    # Get the pairwise similarity scores for all movies with those indices
    sim_scores = []
    for idx in indices:
        sim_scores += list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the indices of the top 10 most similar movies
    movie_indices = [i[0] for i in sim_scores[1:11] if i[0] < len(netFlxDts)]

    # Return the top 10 most similar movies
    return netFlxDts.sort_values(['rating', 'title'], ascending=[False, True]).head(10)

# %%
recommended_movies = get_recommendations('Breaking Bad')
recommended_movies
# Out:
#       movie_ID                            title  year certificate  \
# 17          18                             1899  2022     Unrated
# 7            8                     Breaking Bad  2013       TV-MA
# 3220      3230  Elesin Oba: The King's Horseman  2022     Unrated
# 4638      4664      Story Time Book: Read-Along  2022     Unrated
# 192        194       Avatar: The Last Airbender  2008    TV-Y7-FV
# 781        784      Cosmos: A Spacetime Odyssey  2014       TV-PG
# 1388      1392                       Our Planet  2019        TV-G
# 1193      1197                       Reply 1988  2016     Unrated
# 6            7                   Rick and Morty  2013       TV-MA
# 4340      4364           CM101MMXI Fundamentals  2013     Unrated
#
#       duration_min        genre                           Tag  rating  \
# 17              60        Drama        Drama, History, Horror     9.6
# 7               49        Crime        Crime, Drama, Thriller     9.5
# 3220            96    Adventure     Adventure, Drama, History     9.4
# 4638            70    Animation                     Animation     9.4
# 192             23    Animation  Animation, Action, Adventure     9.3
# 781            557  Documentary                   Documentary     9.3
# 1388           403  Documentary                   Documentary     9.3
# 1193            90       Comedy         Comedy, Drama, Family     9.2
# 6               23    Animation  Animation, Adventure, Comedy     9.2
# 4340           139  Documentary           Documentary, Comedy     9.1
#
#                                             description  \
# 17    Multinational immigrants traveling from the ol...
# 7     A high school chemistry teacher diagnosed with...
# 3220  Inspired by true life events, in the Oyo Empir...
# 4638  Kids can read along with illustrated books tha...
# 192   In a war-torn world of elemental magic, a youn...
# 781   An exploration of our discovery of the laws of...
# 1388  Documentary series focusing on the breadth of ...
# 1193  Follows the lives of 5 families living on the ...
# 6     An animated series that follows the exploits o...
# 4340  The funny little details of everyday life; the...
#
#                                                   stars      votes
# 17    ['Ben Ashenden','Aneurin Barnard','Emily Beech...        853
# 7     ['Bryan Cranston','Aaron Paul','Anna Gunn','Be...  1,831,340
# 3220  ['Biyi Bandele','Odunlade Adekola','Shaffy Bel...         72
# 4638  ['Lileina Joy','Maya Aoki Tuttle','Emily Wold'...         16
# 192   ['Dee Bradley Baker','Zach Tyler Eisen','Mae W...    309,241
# 781   ['Neil deGrasse Tyson','Christopher Emerson','...    121,400
# 1388                             ['David Attenborough']     43,175
# 1193  ['Hyeri Lee','Go Kyung-Pyo','Ryu Jun-Yeol','Pa...      7,286
# 6     ['Justin Roiland','Chris Parnell','Spencer Gra...    502,160
# 4340                      ['Murat Dündar','Cem Yilmaz']     46,282
